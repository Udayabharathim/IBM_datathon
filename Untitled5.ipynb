# %%
pip list
# Out:
# Package                                      Version
# -------------------------------------------- ------------------
# absl-py                                      1.4.0
# aiohappyeyeballs                             2.4.0
# aiohttp                                      3.10.5
# aiosignal                                    1.3.1
# aiosqlite                                    0.20.0
# altair                                       4.2.0
# annotated-types                              0.7.0
# anyio                                        4.4.0
# apistar                                      0.5.41
# appdirs                                      1.4.4
# argon2-cffi                                  23.1.0
# argon2-cffi-bindings                         21.2.0
# arrow                                        1.2.1
# asgiref                                      3.8.1
# asttokens                                    2.4.1
# astunparse                                   1.6.3
# ...
